# %%
import pandas as pd

# %%
data = pd.read_csv('train.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.Survived[data.Pclass == 3][data.Sex == 'female'].head()
# Out:
# 2     1
# 8     1
# 10    1
# 14    0
# 18    0
# Name: Survived, dtype: int64

# %%
data.groupby(['SibSp','Survived']).count()
# Out:
#                 PassengerId  Pclass  Name  Sex  Age  Parch  Ticket  Fare  \
# SibSp Survived
# 0     0                 398     398   398  398  296    398     398   398
#       1                 210     210   210  210  175    210     210   210
# 1     0                  97      97    97   97   86     97      97    97
#       1                 112     112   112  112   97    112     112   112
# 2     0                  15      15    15   15   14     15      15    15
#       1                  13      13    13   13   11     13      13    13
# 3     0                  12      12    12   12    8     12      12    12
#       1                   4       4     4    4    4      4       4     4
# 4     0                  15      15    15   15   15     15      15    15
#       1                   3       3     3    3    3      3       3     3
# 5     0                   5       5     5    5    5      5       5     5
# 8     0                   7       7     7    7    0      7       7     7
#
# ...

# %%
Survived_cabin = data.Survived[pd.notnull(data.Cabin)].value_counts()
Survived_cabin
# Out:
# 1    136
# 0     68
# Name: Survived, dtype: int64

# %%
age_df = data[['Age','Fare', 'Parch', 'SibSp', 'Pclass']]
known_age = age_df[age_df.Age.notnull()].as_matrix()
unknown_age = age_df[age_df.Age.isnull()].as_matrix()
known_age[:, 0]
# Out:
# array([ 22.  ,  38.  ,  26.  ,  35.  ,  35.  ,  54.  ,   2.  ,  27.  ,
#         14.  ,   4.  ,  58.  ,  20.  ,  39.  ,  14.  ,  55.  ,   2.  ,
#         31.  ,  35.  ,  34.  ,  15.  ,  28.  ,   8.  ,  38.  ,  19.  ,
#         40.  ,  66.  ,  28.  ,  42.  ,  21.  ,  18.  ,  14.  ,  40.  ,
#         27.  ,   3.  ,  19.  ,  18.  ,   7.  ,  21.  ,  49.  ,  29.  ,
#         65.  ,  21.  ,  28.5 ,   5.  ,  11.  ,  22.  ,  38.  ,  45.  ,
#          4.  ,  29.  ,  19.  ,  17.  ,  26.  ,  32.  ,  16.  ,  21.  ,
#         26.  ,  32.  ,  25.  ,   0.83,  30.  ,  22.  ,  29.  ,  28.  ,
#         17.  ,  33.  ,  16.  ,  23.  ,  24.  ,  29.  ,  20.  ,  46.  ,
#         26.  ,  59.  ,  71.  ,  23.  ,  34.  ,  34.  ,  28.  ,  21.  ,
#         33.  ,  37.  ,  28.  ,  21.  ,  38.  ,  47.  ,  14.5 ,  22.  ,
#         20.  ,  17.  ,  21.  ,  70.5 ,  29.  ,  24.  ,   2.  ,  21.  ,
#         32.5 ,  32.5 ,  54.  ,  12.  ,  24.  ,  45.  ,  33.  ,  20.  ,
# ...

# %%
unknown_age[:, 1::]
# Out:
# array([[   8.4583,    0.    ,    0.    ,    3.    ],
#        [  13.    ,    0.    ,    0.    ,    2.    ],
#        [   7.225 ,    0.    ,    0.    ,    3.    ],
#        [   7.225 ,    0.    ,    0.    ,    3.    ],
#        [   7.8792,    0.    ,    0.    ,    3.    ],
#        [   7.8958,    0.    ,    0.    ,    3.    ],
#        [ 146.5208,    0.    ,    1.    ,    1.    ],
#        [   7.75  ,    0.    ,    0.    ,    3.    ],
#        [   7.2292,    0.    ,    0.    ,    3.    ],
#        [   7.8958,    0.    ,    0.    ,    3.    ],
#        [   8.05  ,    0.    ,    0.    ,    3.    ],
#        [  15.5   ,    0.    ,    1.    ,    3.    ],
#        [   7.75  ,    0.    ,    0.    ,    3.    ],
#        [  21.6792,    0.    ,    2.    ,    3.    ],
#        [  35.5   ,    0.    ,    0.    ,    1.    ],
#        [  27.7208,    0.    ,    0.    ,    1.    ],
#        [  15.2458,    1.    ,    1.    ,    3.    ],
#        [   7.8958,    0.    ,    0.    ,    3.    ],
# ...

# %%
data.loc[ (data.Age.isnull()), 'Age' ]
# Out:
# 5     NaN
# 17    NaN
# 19    NaN
# 26    NaN
# 28    NaN
# 29    NaN
# 31    NaN
# 32    NaN
# 36    NaN
# 42    NaN
# 45    NaN
# 46    NaN
# 47    NaN
# 48    NaN
# 55    NaN
# 64    NaN
# 65    NaN
# 76    NaN
# 77    NaN
# 82    NaN
# 87    NaN
# 95    NaN
# 101   NaN
# 107   NaN
# 109   NaN
# 121   NaN
# 126   NaN
# 128   NaN
# 140   NaN
# 154   NaN
#        ..
# 718   NaN
# 727   NaN
# 732   NaN
# 738   NaN
# 739   NaN
# 740   NaN
# 760   NaN
# 766   NaN
# 768   NaN
# 773   NaN
# 776   NaN
# 778   NaN
# 783   NaN
# 790   NaN
# 792   NaN
# 793   NaN
# 815   NaN
# 825   NaN
# 826   NaN
# 828   NaN
# 832   NaN
# 837   NaN
# 839   NaN
# 846   NaN
# 849   NaN
# 859   NaN
# 863   NaN
# 868   NaN
# 878   NaN
# 888   NaN
# Name: Age, Length: 177, dtype: float64

# %%
data[data.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
fare = pd.DataFrame(data['Fare'])
fare
# Out:
#          Fare
# 0      7.2500
# 1     71.2833
# 2      7.9250
# 3     53.1000
# 4      8.0500
# 5      8.4583
# 6     51.8625
# 7     21.0750
# 8     11.1333
# 9     30.0708
# 10    16.7000
# 11    26.5500
# 12     8.0500
# 13    31.2750
# 14     7.8542
# 15    16.0000
# 16    29.1250
# 17    13.0000
# 18    18.0000
# 19     7.2250
# 20    26.0000
# 21    13.0000
# 22     8.0292
# 23    35.5000
# 24    21.0750
# 25    31.3875
# 26     7.2250
# 27   263.0000
# 28     7.8792
# 29     7.8958
# ..        ...
# 861   11.5000
# 862   25.9292
# 863   69.5500
# 864   13.0000
# 865   13.0000
# 866   13.8583
# 867   50.4958
# 868    9.5000
# 869   11.1333
# 870    7.8958
# 871   52.5542
# 872    5.0000
# 873    9.0000
# 874   24.0000
# 875    7.2250
# 876    9.8458
# 877    7.8958
# 878    7.8958
# 879   83.1583
# 880   26.0000
# 881    7.8958
# 882   10.5167
# 883   10.5000
# 884    7.0500
# 885   29.1250
# 886   13.0000
# 887   30.0000
# 888   23.4500
# 889   30.0000
# 890    7.7500
#
# ...

# %%
import sklearn.preprocessing as preprocessing
scaler = preprocessing.StandardScaler()
scaler.fit(pd.DataFrame(data['Fare']))
data['Fare_scaled'] = scaler.fit_transform(pd.DataFrame(data['Fare']))
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
fare_scale_param
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.as_matrix()
# Out:
# array([[1, 0, 3, ..., nan, 'S', -0.5024451714361923],
#        [2, 1, 1, ..., 'C85', 'C', 0.7868452935884461],
#        [3, 1, 3, ..., nan, 'S', -0.4888542575852486],
#        ...,
#        [889, 0, 3, ..., nan, 'S', -0.17626323901354432],
#        [890, 1, 1, ..., 'C148', 'C', -0.04438103794142432],
#        [891, 0, 3, ..., nan, 'Q', -0.49237782784290063]], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# Fare_scaled    891 non-null float64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 90.6+ KB

# %%
data[data.Fare_scaled == 0]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Fare_scaled]
# Index: []

# %%
import string

# %%
a = 'i ame ome'
b = 'ame'
string.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-027568ffd84a> in <module>()
#       1 a = 'i ame ome'
#       2 b = 'ame'
# ----> 3 string.find(a, b)
#
# AttributeError: module 'string' has no attribute 'find'

# %%
a.find(b)
# Out:
# 2

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Fare_scaled
# 0      0         A/5 21171   7.2500   NaN        S    -0.502445
# 1      0          PC 17599  71.2833   C85        C     0.786845
# 2      0  STON/O2. 3101282   7.9250   NaN        S    -0.488854
# ...

# %%
data.loc[[0,1]]  # 基于标签，可以是一个，也可以多个，多个要用list表示，（只对行做了索引）
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  Fare_scaled
# 0      0  A/5 21171   7.2500   NaN        S    -0.502445
# 1      0   PC 17599  71.2833   C85        C     0.786845

# %%
data.loc[data.Survived==1]  # 与布尔数组使用，条件选取
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 52            53         1       1
# 53            54         1       2
# 55            56         1       1
# ...

# %%
data.loc[data.Survived==1,['Pclass','Sex']] # 也可以在之后加上column，多个要是list形式
# Out:
#      Pclass     Sex
# 1         1  female
# 2         3  female
# 3         1  female
# 8         3  female
# 9         2  female
# 10        3  female
# 11        1  female
# 15        2  female
# 17        2    male
# 19        3  female
# 21        2    male
# 22        3  female
# 23        1    male
# 25        3  female
# 28        3  female
# 31        1  female
# 32        3  female
# 36        3    male
# 39        3  female
# 43        2  female
# 44        3  female
# 47        3  female
# 52        1  female
# 53        2  female
# 55        1    male
# 56        2  female
# 58        2  female
# 61        1  female
# 65        3    male
# 66        2  female
# ..      ...     ...
# 809       1  female
# 820       1  female
# 821       3    male
# 823       3  female
# 827       2    male
# 828       3    male
# 829       1  female
# 830       3  female
# 831       2    male
# 835       1  female
# 838       3    male
# 839       1    male
# 842       1  female
# ...
